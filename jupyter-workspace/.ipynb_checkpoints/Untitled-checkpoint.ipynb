# %%
import numpy as np

# %% [markdown]
# # Sample code 1

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
L=range(1000)
# %timeit [ i**2 for i in L]
# Out:
# 274 µs ± 4.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
a=np.arrange(1000)
# %timeit a**2
# Out:
# 704 ns ± 13.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
